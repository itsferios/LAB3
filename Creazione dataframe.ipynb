# %% [markdown]
#                         Project done by Michela Pirozzi MAT:732531 and Sara Ferioli MAT:733105

# %% [markdown]
# # LAB 3

# %% [markdown]
# ### Libraries

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ### Functions

# %%
# Method that allow to load ateco csv and prepare the data for the join
def addingAteco():
    df_ateco = pd.read_csv("ateco.csv")
    df_ateco.Descrizione_ateco.replace(r'^.* - ' , '',regex=True, inplace = True,)
    df_ateco = df_ateco.drop("_id",axis=1)
    df_ateco.rename(columns = {"Descrizione_ateco":"SETTOREECONOMICODETTAGLIO"}, inplace = True)
    df_ateco['SETTOREECONOMICODETTAGLIO'] = df_ateco['SETTOREECONOMICODETTAGLIO'].str.upper()
    df_ateco.drop_duplicates(subset="SETTOREECONOMICODETTAGLIO",keep="first",inplace=True)
    return df_ateco

# %%
# Function to transform the columns ETA, nazionalita_transformed, genere_transformed in a unique column
# with the format: "ETA - nazionalita_transformed - genere_transformed"
# syntax:
# df: Dataframe
# column: column name of the new column
def trasformed_input(df,column):
    df[column] = df["Codice_ateco"].apply(str) + " - " + df["titolostudio_transformed"].apply(str)+ " - " + df["modalitalavoro_transformed"].apply(str)+ " - " + df["provincia_transformed"].apply(str)
    return df.drop(labels=['Codice_ateco','titolostudio_transformed','modalitalavoro_transformed','provincia_transformed'], axis=1)

# %%
# Function to retrive the original data from the trasformed ones
# syntax:
# df: Dataframe
# column: column name of the trasformed column
def inverse_trasformed_input(df,column):
    if type(df) is str:
        codice_ateco,titolostudio,modalitalavoro,provincia=df.split(" - ")
        print("Codice_ateco: "+codice_ateco+" titolostudio: "+titolostudio+" modalitalavoro: "+modalitalavoro+" provincia: "+provincia)
        return codice_ateco,titolostudio,modalitalavoro,provincia
    
    df[['Codice_ateco','titolostudio_transformed','modalitalavoro_transformed','provincia_transformed']] = df[column].str.split(" - ",expand=True,)
    return df.drop(labels =[column], axis=1)

# %%
# Function to retrive the original data from the trasformed ones
# syntax:
# value: trasfomed value
# return 'M' if value is 0 otherwise 'F'
def gender(value):
    if value=='0':
        return 'M'
    else:
        return 'F'

# %% [markdown]
# ### Import data and analysis

# %%
# Load the dataframe
attivati = pd.read_csv("Rapporti_di_lavoro_attivati.csv")

# %%
ateco = addingAteco()
ateco
# Out:
#      Codice_ateco                          SETTOREECONOMICODETTAGLIO
# 0              01  COLTIVAZIONI AGRICOLE E PRODUZIONE DI PRODOTTI...
# 1            01.1    COLTIVAZIONE DI COLTURE AGRICOLE NON PERMANENTI
# 2           01.11  COLTIVAZIONE DI CEREALI (ESCLUSO IL RISO), LEG...
# 3         01.11.1          COLTIVAZIONE DI CEREALI (ESCLUSO IL RISO)
# 5         01.11.2                        COLTIVAZIONE DI SEMI OLEOSI
# ...           ...                                                ...
# 3100     96.09.09       ALTRE ATTIVITÀ DI SERVIZI PER LA PERSONA NCA
# 3101           97  ATTIVITÀ DI FAMIGLIE E CONVIVENZE COME DATORI ...
# 3106           98  PRODUZIONE DI BENI E SERVIZI INDIFFERENZIATI P...
# 3107         98.1  PRODUZIONE DI BENI INDIFFERENZIATI PER USO PRO...
# 3111         98.2  PRODUZIONE DI SERVIZI INDIFFERENZIATI PER USO ...
#
# [1853 rows x 2 columns]

# %%
# Transformations of the strings in upper case, to make join
attivati['SETTOREECONOMICODETTAGLIO'] = attivati['SETTOREECONOMICODETTAGLIO'].str.upper()

# %%
# Retrieve only the year from the date
attivati['DATA'] = pd.to_datetime(attivati['DATA'], format="%d/%m/%Y")
attivati['mese-anno'] = attivati['DATA'].apply(lambda x: x.strftime('%Y-%m'))
attivati ['ANNO'] = attivati.DATA.dt.year
attivati = attivati.drop(labels='DATA', axis=1)

# %%
# Join between the two DataFrames
join = pd.merge(attivati, ateco, on =['SETTOREECONOMICODETTAGLIO'], how='inner')
join
# Out:
#         GENERE  ETA                          SETTOREECONOMICODETTAGLIO  \
# 0            F   60  ATTIVITÀ DI FAMIGLIE E CONVIVENZE COME DATORI ...
# 1            F   33  ATTIVITÀ DI FAMIGLIE E CONVIVENZE COME DATORI ...
# 2            F   45  ATTIVITÀ DI FAMIGLIE E CONVIVENZE COME DATORI ...
# 3            F   61  ATTIVITÀ DI FAMIGLIE E CONVIVENZE COME DATORI ...
# 4            F   20  ATTIVITÀ DI FAMIGLIE E CONVIVENZE COME DATORI ...
# ...        ...  ...                                                ...
# 9329690      M   38             TRASPORTO MEDIANTE CONDOTTE DI LIQUIDI
# 9329691      F   40         RICARICA DI BOMBOLE PER ATTIVITÀ SUBACQUEE
# 9329692      M   28         RICARICA DI BOMBOLE PER ATTIVITÀ SUBACQUEE
# 9329693      F   25         RICARICA DI BOMBOLE PER ATTIVITÀ SUBACQUEE
# 9329694      M   24              AGENTI E RAPPRESENTANTI DI GIOCATTOLI
#
#                                               TITOLOSTUDIO  \
# 0                                  NESSUN TITOLO DI STUDIO
# 1                                  NESSUN TITOLO DI STUDIO
# 2                                  NESSUN TITOLO DI STUDIO
# 3                                  NESSUN TITOLO DI STUDIO
# 4                                  NESSUN TITOLO DI STUDIO
# ...                                                    ...
# 9329690                                      LICENZA MEDIA
# 9329691  DIPLOMA DI ISTRUZIONE SECONDARIA SUPERIORE  CH...
# 9329692                                      LICENZA MEDIA
# 9329693  DIPLOMA DI ISTRUZIONE SECONDARIA SUPERIORE  CH...
# 9329694                              DIPLOMA UNIVERSITARIO
#
#                                                  CONTRATTO  \
# 0                                         LAVORO DOMESTICO
# 1                     LAVORO DOMESTICO A TEMPO DETERMINATO
# 2                                         LAVORO DOMESTICO
# 3                                         LAVORO DOMESTICO
# 4                                         LAVORO DOMESTICO
# ...                                                    ...
# 9329690                       LAVORO A TEMPO INDETERMINATO
# 9329691           COLLABORAZIONE COORDINATA E CONTINUATIVA
# 9329692  LAVORO INTERINALE (O A SCOPO DI SOMMINISTRAZIO...
# 9329693           COLLABORAZIONE COORDINATA E CONTINUATIVA
# 9329694                       LAVORO A TEMPO INDETERMINATO
#
#                      MODALITALAVORO PROVINCIAIMPRESA  ITALIANO mese-anno  \
# 0                       TEMPO PIENO          BERGAMO   UCRAINA   2020-05
# 1        TEMPO PARZIALE ORIZZONTALE          BERGAMO  HONDURAS   2012-07
# 2                       TEMPO PIENO          BERGAMO    ITALIA   2019-04
# 3                       TEMPO PIENO            LECCO   UCRAINA   2014-09
# 4        TEMPO PARZIALE ORIZZONTALE            LECCO    ITALIA   2014-05
# ...                             ...              ...       ...       ...
# 9329690                 TEMPO PIENO           MILANO    ITALIA   2020-06
# 9329691                NON DEFINITO          BRESCIA    ITALIA   2021-11
# 9329692                         NaN  MONZA E BRIANZA    ITALIA   2012-08
# 9329693                NON DEFINITO          BRESCIA    ITALIA   2018-11
# 9329694                 TEMPO PIENO             COMO    ITALIA   2015-06
#
#          ANNO Codice_ateco
# 0        2020           97
# 1        2012           97
# 2        2019           97
# 3        2014           97
# 4        2014           97
# ...       ...          ...
# 9329690  2020      49.50.2
# 9329691  2021     93.19.91
# 9329692  2012     93.19.91
# 9329693  2018     93.19.91
# 9329694  2015     46.18.95
#
# [9329695 rows x 11 columns]

# %%
# Obtain only the first two digits of the 'codice ateco' to understand the macro category
join.Codice_ateco.replace(r'^(..)\..*' , r'\1',regex=True, inplace = True,)
join
# Out:
#         GENERE  ETA                          SETTOREECONOMICODETTAGLIO  \
# 0            F   60  ATTIVITÀ DI FAMIGLIE E CONVIVENZE COME DATORI ...
# 1            F   33  ATTIVITÀ DI FAMIGLIE E CONVIVENZE COME DATORI ...
# 2            F   45  ATTIVITÀ DI FAMIGLIE E CONVIVENZE COME DATORI ...
# 3            F   61  ATTIVITÀ DI FAMIGLIE E CONVIVENZE COME DATORI ...
# 4            F   20  ATTIVITÀ DI FAMIGLIE E CONVIVENZE COME DATORI ...
# ...        ...  ...                                                ...
# 9329690      M   38             TRASPORTO MEDIANTE CONDOTTE DI LIQUIDI
# 9329691      F   40         RICARICA DI BOMBOLE PER ATTIVITÀ SUBACQUEE
# 9329692      M   28         RICARICA DI BOMBOLE PER ATTIVITÀ SUBACQUEE
# 9329693      F   25         RICARICA DI BOMBOLE PER ATTIVITÀ SUBACQUEE
# 9329694      M   24              AGENTI E RAPPRESENTANTI DI GIOCATTOLI
#
#                                               TITOLOSTUDIO  \
# 0                                  NESSUN TITOLO DI STUDIO
# 1                                  NESSUN TITOLO DI STUDIO
# 2                                  NESSUN TITOLO DI STUDIO
# 3                                  NESSUN TITOLO DI STUDIO
# 4                                  NESSUN TITOLO DI STUDIO
# ...                                                    ...
# 9329690                                      LICENZA MEDIA
# 9329691  DIPLOMA DI ISTRUZIONE SECONDARIA SUPERIORE  CH...
# 9329692                                      LICENZA MEDIA
# 9329693  DIPLOMA DI ISTRUZIONE SECONDARIA SUPERIORE  CH...
# 9329694                              DIPLOMA UNIVERSITARIO
#
#                                                  CONTRATTO  \
# 0                                         LAVORO DOMESTICO
# 1                     LAVORO DOMESTICO A TEMPO DETERMINATO
# 2                                         LAVORO DOMESTICO
# 3                                         LAVORO DOMESTICO
# 4                                         LAVORO DOMESTICO
# ...                                                    ...
# 9329690                       LAVORO A TEMPO INDETERMINATO
# 9329691           COLLABORAZIONE COORDINATA E CONTINUATIVA
# 9329692  LAVORO INTERINALE (O A SCOPO DI SOMMINISTRAZIO...
# 9329693           COLLABORAZIONE COORDINATA E CONTINUATIVA
# 9329694                       LAVORO A TEMPO INDETERMINATO
#
#                      MODALITALAVORO PROVINCIAIMPRESA  ITALIANO mese-anno  \
# 0                       TEMPO PIENO          BERGAMO   UCRAINA   2020-05
# 1        TEMPO PARZIALE ORIZZONTALE          BERGAMO  HONDURAS   2012-07
# 2                       TEMPO PIENO          BERGAMO    ITALIA   2019-04
# 3                       TEMPO PIENO            LECCO   UCRAINA   2014-09
# 4        TEMPO PARZIALE ORIZZONTALE            LECCO    ITALIA   2014-05
# ...                             ...              ...       ...       ...
# 9329690                 TEMPO PIENO           MILANO    ITALIA   2020-06
# 9329691                NON DEFINITO          BRESCIA    ITALIA   2021-11
# 9329692                         NaN  MONZA E BRIANZA    ITALIA   2012-08
# 9329693                NON DEFINITO          BRESCIA    ITALIA   2018-11
# 9329694                 TEMPO PIENO             COMO    ITALIA   2015-06
#
#          ANNO Codice_ateco
# 0        2020           97
# 1        2012           97
# 2        2019           97
# 3        2014           97
# 4        2014           97
# ...       ...          ...
# 9329690  2020           49
# 9329691  2021           93
# 9329692  2012           93
# 9329693  2018           93
# 9329694  2015           46
#
# [9329695 rows x 11 columns]

# %%
# Extract macro category
join2 = pd.merge(join, ateco, on='Codice_ateco', how='inner')
join2
# Out:
#         GENERE  ETA                        SETTOREECONOMICODETTAGLIO_x  \
# 0            F   60  ATTIVITÀ DI FAMIGLIE E CONVIVENZE COME DATORI ...
# 1            F   33  ATTIVITÀ DI FAMIGLIE E CONVIVENZE COME DATORI ...
# 2            F   45  ATTIVITÀ DI FAMIGLIE E CONVIVENZE COME DATORI ...
# 3            F   61  ATTIVITÀ DI FAMIGLIE E CONVIVENZE COME DATORI ...
# 4            F   20  ATTIVITÀ DI FAMIGLIE E CONVIVENZE COME DATORI ...
# ...        ...  ...                                                ...
# 9329690      M   36                              INDUSTRIA DEL TABACCO
# 9329691      M   35                              INDUSTRIA DEL TABACCO
# 9329692      M   27                              INDUSTRIA DEL TABACCO
# 9329693      M   37                              INDUSTRIA DEL TABACCO
# 9329694      M   36                              INDUSTRIA DEL TABACCO
#
#                                               TITOLOSTUDIO  \
# 0                                  NESSUN TITOLO DI STUDIO
# 1                                  NESSUN TITOLO DI STUDIO
# 2                                  NESSUN TITOLO DI STUDIO
# 3                                  NESSUN TITOLO DI STUDIO
# 4                                  NESSUN TITOLO DI STUDIO
# ...                                                    ...
# 9329690  DIPLOMA DI ISTRUZIONE SECONDARIA SUPERIORE  CH...
# 9329691                            NESSUN TITOLO DI STUDIO
# 9329692                            NESSUN TITOLO DI STUDIO
# 9329693  DIPLOMA DI ISTRUZIONE SECONDARIA SUPERIORE  CH...
# 9329694  DIPLOMA DI ISTRUZIONE SECONDARIA SUPERIORE  CH...
#
#                                                  CONTRATTO  \
# 0                                         LAVORO DOMESTICO
# 1                     LAVORO DOMESTICO A TEMPO DETERMINATO
# 2                                         LAVORO DOMESTICO
# 3                                         LAVORO DOMESTICO
# 4                                         LAVORO DOMESTICO
# ...                                                    ...
# 9329690  LAVORO INTERINALE (O A SCOPO DI SOMMINISTRAZIO...
# 9329691                         LAVORO A TEMPO DETERMINATO
# 9329692                         LAVORO A TEMPO DETERMINATO
# 9329693  LAVORO INTERINALE (O A SCOPO DI SOMMINISTRAZIO...
# 9329694  LAVORO INTERINALE (O A SCOPO DI SOMMINISTRAZIO...
#
#                      MODALITALAVORO PROVINCIAIMPRESA  ITALIANO mese-anno  \
# 0                       TEMPO PIENO          BERGAMO   UCRAINA   2020-05
# 1        TEMPO PARZIALE ORIZZONTALE          BERGAMO  HONDURAS   2012-07
# 2                       TEMPO PIENO          BERGAMO    ITALIA   2019-04
# 3                       TEMPO PIENO            LECCO   UCRAINA   2014-09
# 4        TEMPO PARZIALE ORIZZONTALE            LECCO    ITALIA   2014-05
# ...                             ...              ...       ...       ...
# 9329690                         NaN          BERGAMO    ITALIA   2012-07
# 9329691                 TEMPO PIENO          BRESCIA    ITALIA   2011-07
# 9329692                 TEMPO PIENO           MILANO    ITALIA   2009-04
# 9329693                         NaN          BERGAMO    ITALIA   2012-06
# 9329694                         NaN          BERGAMO    ITALIA   2012-10
#
#          ANNO Codice_ateco                        SETTOREECONOMICODETTAGLIO_y
# 0        2020           97  ATTIVITÀ DI FAMIGLIE E CONVIVENZE COME DATORI ...
# 1        2012           97  ATTIVITÀ DI FAMIGLIE E CONVIVENZE COME DATORI ...
# 2        2019           97  ATTIVITÀ DI FAMIGLIE E CONVIVENZE COME DATORI ...
# 3        2014           97  ATTIVITÀ DI FAMIGLIE E CONVIVENZE COME DATORI ...
# 4        2014           97  ATTIVITÀ DI FAMIGLIE E CONVIVENZE COME DATORI ...
# ...       ...          ...                                                ...
# 9329690  2012           12                              INDUSTRIA DEL TABACCO
# 9329691  2011           12                              INDUSTRIA DEL TABACCO
# 9329692  2009           12                              INDUSTRIA DEL TABACCO
# 9329693  2012           12                              INDUSTRIA DEL TABACCO
# 9329694  2012           12                              INDUSTRIA DEL TABACCO
#
# [9329695 rows x 12 columns]

# %%
# Delete the sub category
join2 = join2.drop(labels='SETTOREECONOMICODETTAGLIO_x', axis=1)

# %%
# Transformations of the strings in upper case, to make a match, without problem
join2['CONTRATTO']=join2['CONTRATTO'].str.upper()
join2
# Out:
#         GENERE  ETA                                       TITOLOSTUDIO  \
# 0            F   60                            NESSUN TITOLO DI STUDIO
# 1            F   33                            NESSUN TITOLO DI STUDIO
# 2            F   45                            NESSUN TITOLO DI STUDIO
# 3            F   61                            NESSUN TITOLO DI STUDIO
# 4            F   20                            NESSUN TITOLO DI STUDIO
# ...        ...  ...                                                ...
# 9329690      M   36  DIPLOMA DI ISTRUZIONE SECONDARIA SUPERIORE  CH...
# 9329691      M   35                            NESSUN TITOLO DI STUDIO
# 9329692      M   27                            NESSUN TITOLO DI STUDIO
# 9329693      M   37  DIPLOMA DI ISTRUZIONE SECONDARIA SUPERIORE  CH...
# 9329694      M   36  DIPLOMA DI ISTRUZIONE SECONDARIA SUPERIORE  CH...
#
#                                                  CONTRATTO  \
# 0                                         LAVORO DOMESTICO
# 1                     LAVORO DOMESTICO A TEMPO DETERMINATO
# 2                                         LAVORO DOMESTICO
# 3                                         LAVORO DOMESTICO
# 4                                         LAVORO DOMESTICO
# ...                                                    ...
# 9329690  LAVORO INTERINALE (O A SCOPO DI SOMMINISTRAZIO...
# 9329691                         LAVORO A TEMPO DETERMINATO
# 9329692                         LAVORO A TEMPO DETERMINATO
# 9329693  LAVORO INTERINALE (O A SCOPO DI SOMMINISTRAZIO...
# 9329694  LAVORO INTERINALE (O A SCOPO DI SOMMINISTRAZIO...
#
#                      MODALITALAVORO PROVINCIAIMPRESA  ITALIANO mese-anno  \
# 0                       TEMPO PIENO          BERGAMO   UCRAINA   2020-05
# 1        TEMPO PARZIALE ORIZZONTALE          BERGAMO  HONDURAS   2012-07
# 2                       TEMPO PIENO          BERGAMO    ITALIA   2019-04
# 3                       TEMPO PIENO            LECCO   UCRAINA   2014-09
# 4        TEMPO PARZIALE ORIZZONTALE            LECCO    ITALIA   2014-05
# ...                             ...              ...       ...       ...
# 9329690                         NaN          BERGAMO    ITALIA   2012-07
# 9329691                 TEMPO PIENO          BRESCIA    ITALIA   2011-07
# 9329692                 TEMPO PIENO           MILANO    ITALIA   2009-04
# 9329693                         NaN          BERGAMO    ITALIA   2012-06
# 9329694                         NaN          BERGAMO    ITALIA   2012-10
#
#          ANNO Codice_ateco                        SETTOREECONOMICODETTAGLIO_y
# 0        2020           97  ATTIVITÀ DI FAMIGLIE E CONVIVENZE COME DATORI ...
# 1        2012           97  ATTIVITÀ DI FAMIGLIE E CONVIVENZE COME DATORI ...
# 2        2019           97  ATTIVITÀ DI FAMIGLIE E CONVIVENZE COME DATORI ...
# 3        2014           97  ATTIVITÀ DI FAMIGLIE E CONVIVENZE COME DATORI ...
# 4        2014           97  ATTIVITÀ DI FAMIGLIE E CONVIVENZE COME DATORI ...
# ...       ...          ...                                                ...
# 9329690  2012           12                              INDUSTRIA DEL TABACCO
# 9329691  2011           12                              INDUSTRIA DEL TABACCO
# 9329692  2009           12                              INDUSTRIA DEL TABACCO
# 9329693  2012           12                              INDUSTRIA DEL TABACCO
# 9329694  2012           12                              INDUSTRIA DEL TABACCO
#
# [9329695 rows x 11 columns]

# %%
# Set generic category for the contracts 
join2.loc[join2['CONTRATTO'].str.match(r'.*INDETERMINATO.*') == True,"CONTRATTO"]="INDETERMINATO"
join2.loc[join2['CONTRATTO'].str.match(r'.*INDETERMINATO.*') == False,"CONTRATTO"]="NON INDETERMINATO"

indeterminato=join2
indeterminato
# Out:
#         GENERE  ETA                                       TITOLOSTUDIO  \
# 0            F   60                            NESSUN TITOLO DI STUDIO
# 1            F   33                            NESSUN TITOLO DI STUDIO
# 2            F   45                            NESSUN TITOLO DI STUDIO
# 3            F   61                            NESSUN TITOLO DI STUDIO
# 4            F   20                            NESSUN TITOLO DI STUDIO
# ...        ...  ...                                                ...
# 9329690      M   36  DIPLOMA DI ISTRUZIONE SECONDARIA SUPERIORE  CH...
# 9329691      M   35                            NESSUN TITOLO DI STUDIO
# 9329692      M   27                            NESSUN TITOLO DI STUDIO
# 9329693      M   37  DIPLOMA DI ISTRUZIONE SECONDARIA SUPERIORE  CH...
# 9329694      M   36  DIPLOMA DI ISTRUZIONE SECONDARIA SUPERIORE  CH...
#
#                  CONTRATTO              MODALITALAVORO PROVINCIAIMPRESA  \
# 0        NON INDETERMINATO                 TEMPO PIENO          BERGAMO
# 1        NON INDETERMINATO  TEMPO PARZIALE ORIZZONTALE          BERGAMO
# 2        NON INDETERMINATO                 TEMPO PIENO          BERGAMO
# 3        NON INDETERMINATO                 TEMPO PIENO            LECCO
# 4        NON INDETERMINATO  TEMPO PARZIALE ORIZZONTALE            LECCO
# ...                    ...                         ...              ...
# 9329690  NON INDETERMINATO                         NaN          BERGAMO
# 9329691  NON INDETERMINATO                 TEMPO PIENO          BRESCIA
# 9329692  NON INDETERMINATO                 TEMPO PIENO           MILANO
# 9329693  NON INDETERMINATO                         NaN          BERGAMO
# 9329694  NON INDETERMINATO                         NaN          BERGAMO
#
#          ITALIANO mese-anno  ANNO Codice_ateco  \
# 0         UCRAINA   2020-05  2020           97
# 1        HONDURAS   2012-07  2012           97
# 2          ITALIA   2019-04  2019           97
# 3         UCRAINA   2014-09  2014           97
# 4          ITALIA   2014-05  2014           97
# ...           ...       ...   ...          ...
# 9329690    ITALIA   2012-07  2012           12
# 9329691    ITALIA   2011-07  2011           12
# 9329692    ITALIA   2009-04  2009           12
# 9329693    ITALIA   2012-06  2012           12
# 9329694    ITALIA   2012-10  2012           12
#
#                                SETTOREECONOMICODETTAGLIO_y
# 0        ATTIVITÀ DI FAMIGLIE E CONVIVENZE COME DATORI ...
# 1        ATTIVITÀ DI FAMIGLIE E CONVIVENZE COME DATORI ...
# 2        ATTIVITÀ DI FAMIGLIE E CONVIVENZE COME DATORI ...
# 3        ATTIVITÀ DI FAMIGLIE E CONVIVENZE COME DATORI ...
# 4        ATTIVITÀ DI FAMIGLIE E CONVIVENZE COME DATORI ...
# ...                                                    ...
# 9329690                              INDUSTRIA DEL TABACCO
# 9329691                              INDUSTRIA DEL TABACCO
# 9329692                              INDUSTRIA DEL TABACCO
# 9329693                              INDUSTRIA DEL TABACCO
# 9329694                              INDUSTRIA DEL TABACCO
#
# [9329695 rows x 11 columns]

# %% [markdown]
# ### Label Encoder

# %%
# Starting the procedure to encode the data
titolostudio = indeterminato.TITOLOSTUDIO.tolist()
modlavoro = indeterminato.MODALITALAVORO.tolist()
prov = indeterminato.PROVINCIAIMPRESA.tolist()
nazionalita = indeterminato.ITALIANO.tolist()
copia = indeterminato.copy()

# %%
# Instantiate labelencoder object for each column that we want to encode
le_titolostudio = LabelEncoder()
le_modlavoro = LabelEncoder()
le_prov = LabelEncoder()
le_nazionalita = LabelEncoder()

# %%
# Apply the label encoder to the dataset
le_titolostudio.fit(copia['TITOLOSTUDIO'])
le_modlavoro.fit(copia['MODALITALAVORO'])
le_prov.fit(copia['PROVINCIAIMPRESA'])
le_nazionalita.fit(copia['ITALIANO'])
# Out:
# LabelEncoder()

# %%
# Transform into integers
transformation_ts = le_titolostudio.transform(indeterminato['TITOLOSTUDIO']) 
transformation_ts
# Out:
# array([8, 8, 8, ..., 8, 0, 0])

# %%
# Try to invert a transformation using the object
list(le_titolostudio.inverse_transform([8]))
# Out:
# ['NESSUN TITOLO DI STUDIO']

# %%
# Transform into integers
transformation_ml = le_modlavoro.transform(indeterminato['MODALITALAVORO']) 
transformation_prov = le_prov.transform(indeterminato['PROVINCIAIMPRESA']) 
transformation_nazion = le_nazionalita.transform(indeterminato['ITALIANO'])

# %%
# Apply label encoder on categorical feature columns
copia['titolostudio_transformed'] = list(transformation_ts)
copia['modalitalavoro_transformed'] = list(transformation_ml)
copia['provincia_transformed'] = list(transformation_prov)
copia['nazionalita_transformed'] = list(transformation_nazion)
copia
# Out:
#         GENERE  ETA                                       TITOLOSTUDIO  \
# 0            F   60                            NESSUN TITOLO DI STUDIO
# 1            F   33                            NESSUN TITOLO DI STUDIO
# 2            F   45                            NESSUN TITOLO DI STUDIO
# 3            F   61                            NESSUN TITOLO DI STUDIO
# 4            F   20                            NESSUN TITOLO DI STUDIO
# ...        ...  ...                                                ...
# 9329690      M   36  DIPLOMA DI ISTRUZIONE SECONDARIA SUPERIORE  CH...
# 9329691      M   35                            NESSUN TITOLO DI STUDIO
# 9329692      M   27                            NESSUN TITOLO DI STUDIO
# 9329693      M   37  DIPLOMA DI ISTRUZIONE SECONDARIA SUPERIORE  CH...
# 9329694      M   36  DIPLOMA DI ISTRUZIONE SECONDARIA SUPERIORE  CH...
#
#                  CONTRATTO              MODALITALAVORO PROVINCIAIMPRESA  \
# 0        NON INDETERMINATO                 TEMPO PIENO          BERGAMO
# 1        NON INDETERMINATO  TEMPO PARZIALE ORIZZONTALE          BERGAMO
# 2        NON INDETERMINATO                 TEMPO PIENO          BERGAMO
# 3        NON INDETERMINATO                 TEMPO PIENO            LECCO
# 4        NON INDETERMINATO  TEMPO PARZIALE ORIZZONTALE            LECCO
# ...                    ...                         ...              ...
# 9329690  NON INDETERMINATO                         NaN          BERGAMO
# 9329691  NON INDETERMINATO                 TEMPO PIENO          BRESCIA
# 9329692  NON INDETERMINATO                 TEMPO PIENO           MILANO
# 9329693  NON INDETERMINATO                         NaN          BERGAMO
# 9329694  NON INDETERMINATO                         NaN          BERGAMO
#
#          ITALIANO mese-anno  ANNO Codice_ateco  \
# 0         UCRAINA   2020-05  2020           97
# 1        HONDURAS   2012-07  2012           97
# 2          ITALIA   2019-04  2019           97
# 3         UCRAINA   2014-09  2014           97
# 4          ITALIA   2014-05  2014           97
# ...           ...       ...   ...          ...
# 9329690    ITALIA   2012-07  2012           12
# 9329691    ITALIA   2011-07  2011           12
# 9329692    ITALIA   2009-04  2009           12
# 9329693    ITALIA   2012-06  2012           12
# 9329694    ITALIA   2012-10  2012           12
#
#                                SETTOREECONOMICODETTAGLIO_y  \
# 0        ATTIVITÀ DI FAMIGLIE E CONVIVENZE COME DATORI ...
# 1        ATTIVITÀ DI FAMIGLIE E CONVIVENZE COME DATORI ...
# 2        ATTIVITÀ DI FAMIGLIE E CONVIVENZE COME DATORI ...
# 3        ATTIVITÀ DI FAMIGLIE E CONVIVENZE COME DATORI ...
# 4        ATTIVITÀ DI FAMIGLIE E CONVIVENZE COME DATORI ...
# ...                                                    ...
# 9329690                              INDUSTRIA DEL TABACCO
# 9329691                              INDUSTRIA DEL TABACCO
# 9329692                              INDUSTRIA DEL TABACCO
# 9329693                              INDUSTRIA DEL TABACCO
# 9329694                              INDUSTRIA DEL TABACCO
#
#          titolostudio_transformed  modalitalavoro_transformed  \
# 0                               8                           4
# 1                               8                           2
# 2                               8                           4
# 3                               8                           4
# 4                               8                           2
# ...                           ...                         ...
# 9329690                         0                           5
# 9329691                         8                           4
# 9329692                         8                           4
# 9329693                         0                           5
# 9329694                         0                           5
#
#          provincia_transformed  nazionalita_transformed
# 0                            0                      188
# 1                            0                       81
# 2                            0                       89
# 3                            4                      188
# 4                            4                       89
# ...                        ...                      ...
# 9329690                      0                       89
# 9329691                      1                       89
# 9329692                      7                       89
# 9329693                      0                       89
# 9329694                      0                       89
#
# [9329695 rows x 15 columns]

# %% [markdown]
# ### Encoding Manually Ordinal Categorical Features

# %%
# Create mapper
scale_mapper = {'NON INDETERMINATO':0, 'INDETERMINATO':1}

# Map feature values to scale
copia['contratto_transformed'] = copia['CONTRATTO'].replace(scale_mapper)
copia
# Out:
#         GENERE  ETA                                       TITOLOSTUDIO  \
# 0            F   60                            NESSUN TITOLO DI STUDIO
# 1            F   33                            NESSUN TITOLO DI STUDIO
# 2            F   45                            NESSUN TITOLO DI STUDIO
# 3            F   61                            NESSUN TITOLO DI STUDIO
# 4            F   20                            NESSUN TITOLO DI STUDIO
# ...        ...  ...                                                ...
# 9329690      M   36  DIPLOMA DI ISTRUZIONE SECONDARIA SUPERIORE  CH...
# 9329691      M   35                            NESSUN TITOLO DI STUDIO
# 9329692      M   27                            NESSUN TITOLO DI STUDIO
# 9329693      M   37  DIPLOMA DI ISTRUZIONE SECONDARIA SUPERIORE  CH...
# 9329694      M   36  DIPLOMA DI ISTRUZIONE SECONDARIA SUPERIORE  CH...
#
#                  CONTRATTO              MODALITALAVORO PROVINCIAIMPRESA  \
# 0        NON INDETERMINATO                 TEMPO PIENO          BERGAMO
# 1        NON INDETERMINATO  TEMPO PARZIALE ORIZZONTALE          BERGAMO
# 2        NON INDETERMINATO                 TEMPO PIENO          BERGAMO
# 3        NON INDETERMINATO                 TEMPO PIENO            LECCO
# 4        NON INDETERMINATO  TEMPO PARZIALE ORIZZONTALE            LECCO
# ...                    ...                         ...              ...
# 9329690  NON INDETERMINATO                         NaN          BERGAMO
# 9329691  NON INDETERMINATO                 TEMPO PIENO          BRESCIA
# 9329692  NON INDETERMINATO                 TEMPO PIENO           MILANO
# 9329693  NON INDETERMINATO                         NaN          BERGAMO
# 9329694  NON INDETERMINATO                         NaN          BERGAMO
#
#          ITALIANO mese-anno  ANNO Codice_ateco  \
# 0         UCRAINA   2020-05  2020           97
# 1        HONDURAS   2012-07  2012           97
# 2          ITALIA   2019-04  2019           97
# 3         UCRAINA   2014-09  2014           97
# 4          ITALIA   2014-05  2014           97
# ...           ...       ...   ...          ...
# 9329690    ITALIA   2012-07  2012           12
# 9329691    ITALIA   2011-07  2011           12
# 9329692    ITALIA   2009-04  2009           12
# 9329693    ITALIA   2012-06  2012           12
# 9329694    ITALIA   2012-10  2012           12
#
#                                SETTOREECONOMICODETTAGLIO_y  \
# 0        ATTIVITÀ DI FAMIGLIE E CONVIVENZE COME DATORI ...
# 1        ATTIVITÀ DI FAMIGLIE E CONVIVENZE COME DATORI ...
# 2        ATTIVITÀ DI FAMIGLIE E CONVIVENZE COME DATORI ...
# 3        ATTIVITÀ DI FAMIGLIE E CONVIVENZE COME DATORI ...
# 4        ATTIVITÀ DI FAMIGLIE E CONVIVENZE COME DATORI ...
# ...                                                    ...
# 9329690                              INDUSTRIA DEL TABACCO
# 9329691                              INDUSTRIA DEL TABACCO
# 9329692                              INDUSTRIA DEL TABACCO
# 9329693                              INDUSTRIA DEL TABACCO
# 9329694                              INDUSTRIA DEL TABACCO
#
#          titolostudio_transformed  modalitalavoro_transformed  \
# 0                               8                           4
# 1                               8                           2
# 2                               8                           4
# 3                               8                           4
# 4                               8                           2
# ...                           ...                         ...
# 9329690                         0                           5
# 9329691                         8                           4
# 9329692                         8                           4
# 9329693                         0                           5
# 9329694                         0                           5
#
#          provincia_transformed  nazionalita_transformed  contratto_transformed
# 0                            0                      188                      0
# 1                            0                       81                      0
# 2                            0                       89                      0
# 3                            4                      188                      0
# 4                            4                       89                      0
# ...                        ...                      ...                    ...
# 9329690                      0                       89                      0
# 9329691                      1                       89                      0
# 9329692                      7                       89                      0
# 9329693                      0                       89                      0
# 9329694                      0                       89                      0
#
# [9329695 rows x 16 columns]

# %%
# Create mapper
scale_mapper = {'M':0, 'F':1}

# Map feature values to scale
copia['genere_transformed'] = copia['GENERE'].replace(scale_mapper)
copia
# Out:
#         GENERE  ETA                                       TITOLOSTUDIO  \
# 0            F   60                            NESSUN TITOLO DI STUDIO
# 1            F   33                            NESSUN TITOLO DI STUDIO
# 2            F   45                            NESSUN TITOLO DI STUDIO
# 3            F   61                            NESSUN TITOLO DI STUDIO
# 4            F   20                            NESSUN TITOLO DI STUDIO
# ...        ...  ...                                                ...
# 9329690      M   36  DIPLOMA DI ISTRUZIONE SECONDARIA SUPERIORE  CH...
# 9329691      M   35                            NESSUN TITOLO DI STUDIO
# 9329692      M   27                            NESSUN TITOLO DI STUDIO
# 9329693      M   37  DIPLOMA DI ISTRUZIONE SECONDARIA SUPERIORE  CH...
# 9329694      M   36  DIPLOMA DI ISTRUZIONE SECONDARIA SUPERIORE  CH...
#
#                  CONTRATTO              MODALITALAVORO PROVINCIAIMPRESA  \
# 0        NON INDETERMINATO                 TEMPO PIENO          BERGAMO
# 1        NON INDETERMINATO  TEMPO PARZIALE ORIZZONTALE          BERGAMO
# 2        NON INDETERMINATO                 TEMPO PIENO          BERGAMO
# 3        NON INDETERMINATO                 TEMPO PIENO            LECCO
# 4        NON INDETERMINATO  TEMPO PARZIALE ORIZZONTALE            LECCO
# ...                    ...                         ...              ...
# 9329690  NON INDETERMINATO                         NaN          BERGAMO
# 9329691  NON INDETERMINATO                 TEMPO PIENO          BRESCIA
# 9329692  NON INDETERMINATO                 TEMPO PIENO           MILANO
# 9329693  NON INDETERMINATO                         NaN          BERGAMO
# 9329694  NON INDETERMINATO                         NaN          BERGAMO
#
#          ITALIANO mese-anno  ANNO Codice_ateco  \
# 0         UCRAINA   2020-05  2020           97
# 1        HONDURAS   2012-07  2012           97
# 2          ITALIA   2019-04  2019           97
# 3         UCRAINA   2014-09  2014           97
# 4          ITALIA   2014-05  2014           97
# ...           ...       ...   ...          ...
# 9329690    ITALIA   2012-07  2012           12
# 9329691    ITALIA   2011-07  2011           12
# 9329692    ITALIA   2009-04  2009           12
# 9329693    ITALIA   2012-06  2012           12
# 9329694    ITALIA   2012-10  2012           12
#
#                                SETTOREECONOMICODETTAGLIO_y  \
# 0        ATTIVITÀ DI FAMIGLIE E CONVIVENZE COME DATORI ...
# 1        ATTIVITÀ DI FAMIGLIE E CONVIVENZE COME DATORI ...
# 2        ATTIVITÀ DI FAMIGLIE E CONVIVENZE COME DATORI ...
# 3        ATTIVITÀ DI FAMIGLIE E CONVIVENZE COME DATORI ...
# 4        ATTIVITÀ DI FAMIGLIE E CONVIVENZE COME DATORI ...
# ...                                                    ...
# 9329690                              INDUSTRIA DEL TABACCO
# 9329691                              INDUSTRIA DEL TABACCO
# 9329692                              INDUSTRIA DEL TABACCO
# 9329693                              INDUSTRIA DEL TABACCO
# 9329694                              INDUSTRIA DEL TABACCO
#
#          titolostudio_transformed  modalitalavoro_transformed  \
# 0                               8                           4
# 1                               8                           2
# 2                               8                           4
# 3                               8                           4
# 4                               8                           2
# ...                           ...                         ...
# 9329690                         0                           5
# 9329691                         8                           4
# 9329692                         8                           4
# 9329693                         0                           5
# 9329694                         0                           5
#
#          provincia_transformed  nazionalita_transformed  \
# 0                            0                      188
# 1                            0                       81
# 2                            0                       89
# 3                            4                      188
# 4                            4                       89
# ...                        ...                      ...
# 9329690                      0                       89
# 9329691                      1                       89
# 9329692                      7                       89
# 9329693                      0                       89
# 9329694                      0                       89
#
#          contratto_transformed  genere_transformed
# 0                            0                   1
# 1                            0                   1
# 2                            0                   1
# 3                            0                   1
# 4                            0                   1
# ...                        ...                 ...
# 9329690                      0                   0
# 9329691                      0                   0
# 9329692                      0                   0
# 9329693                      0                   0
# 9329694                      0                   0
#
# [9329695 rows x 17 columns]

# %%
# Trasform the column in int type
copia['Codice_ateco']=copia.Codice_ateco.astype(int)

# We remove the outliers. 
copia = copia[copia['ETA']>=15]
copia = copia[copia['ETA']<100]
copia = copia[copia['ANNO']<2022]
copia = copia[copia['ANNO']>2006]
copia
# Out:
#         GENERE  ETA                                       TITOLOSTUDIO  \
# 0            F   60                            NESSUN TITOLO DI STUDIO
# 1            F   33                            NESSUN TITOLO DI STUDIO
# 2            F   45                            NESSUN TITOLO DI STUDIO
# 3            F   61                            NESSUN TITOLO DI STUDIO
# 4            F   20                            NESSUN TITOLO DI STUDIO
# ...        ...  ...                                                ...
# 9329690      M   36  DIPLOMA DI ISTRUZIONE SECONDARIA SUPERIORE  CH...
# 9329691      M   35                            NESSUN TITOLO DI STUDIO
# 9329692      M   27                            NESSUN TITOLO DI STUDIO
# 9329693      M   37  DIPLOMA DI ISTRUZIONE SECONDARIA SUPERIORE  CH...
# 9329694      M   36  DIPLOMA DI ISTRUZIONE SECONDARIA SUPERIORE  CH...
#
#                  CONTRATTO              MODALITALAVORO PROVINCIAIMPRESA  \
# 0        NON INDETERMINATO                 TEMPO PIENO          BERGAMO
# 1        NON INDETERMINATO  TEMPO PARZIALE ORIZZONTALE          BERGAMO
# 2        NON INDETERMINATO                 TEMPO PIENO          BERGAMO
# 3        NON INDETERMINATO                 TEMPO PIENO            LECCO
# 4        NON INDETERMINATO  TEMPO PARZIALE ORIZZONTALE            LECCO
# ...                    ...                         ...              ...
# 9329690  NON INDETERMINATO                         NaN          BERGAMO
# 9329691  NON INDETERMINATO                 TEMPO PIENO          BRESCIA
# 9329692  NON INDETERMINATO                 TEMPO PIENO           MILANO
# 9329693  NON INDETERMINATO                         NaN          BERGAMO
# 9329694  NON INDETERMINATO                         NaN          BERGAMO
#
#          ITALIANO mese-anno  ANNO  Codice_ateco  \
# 0         UCRAINA   2020-05  2020            97
# 1        HONDURAS   2012-07  2012            97
# 2          ITALIA   2019-04  2019            97
# 3         UCRAINA   2014-09  2014            97
# 4          ITALIA   2014-05  2014            97
# ...           ...       ...   ...           ...
# 9329690    ITALIA   2012-07  2012            12
# 9329691    ITALIA   2011-07  2011            12
# 9329692    ITALIA   2009-04  2009            12
# 9329693    ITALIA   2012-06  2012            12
# 9329694    ITALIA   2012-10  2012            12
#
#                                SETTOREECONOMICODETTAGLIO_y  \
# 0        ATTIVITÀ DI FAMIGLIE E CONVIVENZE COME DATORI ...
# 1        ATTIVITÀ DI FAMIGLIE E CONVIVENZE COME DATORI ...
# 2        ATTIVITÀ DI FAMIGLIE E CONVIVENZE COME DATORI ...
# 3        ATTIVITÀ DI FAMIGLIE E CONVIVENZE COME DATORI ...
# 4        ATTIVITÀ DI FAMIGLIE E CONVIVENZE COME DATORI ...
# ...                                                    ...
# 9329690                              INDUSTRIA DEL TABACCO
# 9329691                              INDUSTRIA DEL TABACCO
# 9329692                              INDUSTRIA DEL TABACCO
# 9329693                              INDUSTRIA DEL TABACCO
# 9329694                              INDUSTRIA DEL TABACCO
#
#          titolostudio_transformed  modalitalavoro_transformed  \
# 0                               8                           4
# 1                               8                           2
# 2                               8                           4
# 3                               8                           4
# 4                               8                           2
# ...                           ...                         ...
# 9329690                         0                           5
# 9329691                         8                           4
# 9329692                         8                           4
# 9329693                         0                           5
# 9329694                         0                           5
#
#          provincia_transformed  nazionalita_transformed  \
# 0                            0                      188
# 1                            0                       81
# 2                            0                       89
# 3                            4                      188
# 4                            4                       89
# ...                        ...                      ...
# 9329690                      0                       89
# 9329691                      1                       89
# 9329692                      7                       89
# 9329693                      0                       89
# 9329694                      0                       89
#
#          contratto_transformed  genere_transformed
# 0                            0                   1
# 1                            0                   1
# 2                            0                   1
# 3                            0                   1
# 4                            0                   1
# ...                        ...                 ...
# 9329690                      0                   0
# 9329691                      0                   0
# 9329692                      0                   0
# 9329693                      0                   0
# 9329694                      0                   0
#
# [9317603 rows x 17 columns]

# %%
# Drop the columns that have been transformed
transformed_indet = copia.drop(labels =['GENERE', 'TITOLOSTUDIO', 'MODALITALAVORO', 'PROVINCIAIMPRESA', 'ITALIANO', 'SETTOREECONOMICODETTAGLIO_y', 'CONTRATTO'], axis=1)
transformed_indet
# Out:
#          ETA mese-anno  ANNO  Codice_ateco  titolostudio_transformed  \
# 0         60   2020-05  2020            97                         8
# 1         33   2012-07  2012            97                         8
# 2         45   2019-04  2019            97                         8
# 3         61   2014-09  2014            97                         8
# 4         20   2014-05  2014            97                         8
# ...      ...       ...   ...           ...                       ...
# 9329690   36   2012-07  2012            12                         0
# 9329691   35   2011-07  2011            12                         8
# 9329692   27   2009-04  2009            12                         8
# 9329693   37   2012-06  2012            12                         0
# 9329694   36   2012-10  2012            12                         0
#
#          modalitalavoro_transformed  provincia_transformed  \
# 0                                 4                      0
# 1                                 2                      0
# 2                                 4                      0
# 3                                 4                      4
# 4                                 2                      4
# ...                             ...                    ...
# 9329690                           5                      0
# 9329691                           4                      1
# 9329692                           4                      7
# 9329693                           5                      0
# 9329694                           5                      0
#
#          nazionalita_transformed  contratto_transformed  genere_transformed
# 0                            188                      0                   1
# 1                             81                      0                   1
# 2                             89                      0                   1
# 3                            188                      0                   1
# 4                             89                      0                   1
# ...                          ...                    ...                 ...
# 9329690                       89                      0                   0
# 9329691                       89                      0                   0
# 9329692                       89                      0                   0
# 9329693                       89                      0                   0
# 9329694                       89                      0                   0
#
# [9317603 rows x 10 columns]

# %%
# Change the type of all column
transformed_indet['Codice_ateco'] = transformed_indet['Codice_ateco'].astype(str).astype(int)
transformed_indet.dtypes
# Out:
# ETA                            int64
# mese-anno                     object
# ANNO                           int64
# Codice_ateco                   int32
# titolostudio_transformed       int32
# modalitalavoro_transformed     int32
# provincia_transformed          int32
# nazionalita_transformed        int32
# contratto_transformed          int64
# genere_transformed             int64
# dtype: object

# %%
# Encoding of the input
transformed_indet=trasformed_input(transformed_indet,'Output')
transformed_indet
# Out:
#          ETA mese-anno  ANNO  nazionalita_transformed  contratto_transformed  \
# 0         60   2020-05  2020                      188                      0
# 1         33   2012-07  2012                       81                      0
# 2         45   2019-04  2019                       89                      0
# 3         61   2014-09  2014                      188                      0
# 4         20   2014-05  2014                       89                      0
# ...      ...       ...   ...                      ...                    ...
# 9329690   36   2012-07  2012                       89                      0
# 9329691   35   2011-07  2011                       89                      0
# 9329692   27   2009-04  2009                       89                      0
# 9329693   37   2012-06  2012                       89                      0
# 9329694   36   2012-10  2012                       89                      0
#
#          genere_transformed          Output
# 0                         1  97 - 8 - 4 - 0
# 1                         1  97 - 8 - 2 - 0
# 2                         1  97 - 8 - 4 - 0
# 3                         1  97 - 8 - 4 - 4
# 4                         1  97 - 8 - 2 - 4
# ...                     ...             ...
# 9329690                   0  12 - 0 - 5 - 0
# 9329691                   0  12 - 8 - 4 - 1
# 9329692                   0  12 - 8 - 4 - 7
# 9329693                   0  12 - 0 - 5 - 0
# 9329694                   0  12 - 0 - 5 - 0
#
# [9317603 rows x 7 columns]

# %%
# With LabelEncoder we encode the input column
copia = transformed_indet.copy()
le_output = LabelEncoder()
le_output.fit(copia['Output'])
transformation_output = le_output.transform(transformed_indet['Output']) 
copia['Output_transformed'] = list(transformation_output)
copia=copia.drop(labels =['Output'], axis=1)
copia
# Out:
#          ETA mese-anno  ANNO  nazionalita_transformed  contratto_transformed  \
# 0         60   2020-05  2020                      188                      0
# 1         33   2012-07  2012                       81                      0
# 2         45   2019-04  2019                       89                      0
# 3         61   2014-09  2014                      188                      0
# 4         20   2014-05  2014                       89                      0
# ...      ...       ...   ...                      ...                    ...
# 9329690   36   2012-07  2012                       89                      0
# 9329691   35   2011-07  2011                       89                      0
# 9329692   27   2009-04  2009                       89                      0
# 9329693   37   2012-06  2012                       89                      0
# 9329694   36   2012-10  2012                       89                      0
#
#          genere_transformed  Output_transformed
# 0                         1               32612
# 1                         1               32591
# 2                         1               32612
# 3                         1               32618
# 4                         1               32597
# ...                     ...                 ...
# 9329690                   0                1349
# 9329691                   0                1350
# 9329692                   0                1351
# 9329693                   0                1349
# 9329694                   0                1349
#
# [9317603 rows x 7 columns]

# %%
copia.to_csv('transformed.csv')
